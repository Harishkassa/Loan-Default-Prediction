# %% [markdown]
# ## Industry rule for this stage
#
# **Rule:** any binning, ratio, or derived-column logic must be defined once and applied identically to both train and test — the function that creates a feature should never see the word "test" branch differently except for which frozen train-fit parameters it re-uses.

# %%
# NOTE (dependency not included in this zip): `ml_project` is a custom local package
# providing helper functions used below (e.g. fill_with_group_median, detect_outliers_and_capping,
# convert_binary_to_bool, generate_binning_column, apply_binning_test). Its source was not part of
# the uploaded files, so this cell will fail until that package is placed on the Python path.
# Industry rule: shared helper functions like these belong in a versioned, importable package/module
# (or a src/ folder), never only on one person's local machine path.
from ml_project import *  # see note above
import sys

from ml_project import *

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_eda = pd.read_csv("../data/processed/df_eda.csv")
test_df = pd.read_csv("../data/processed/test_df_cleaned.csv")

df_eda.head()
# Out:
#     Age    Income Home_ownership  Employment_length      Loan_intent  \
# 0  23.0   75800.0           Rent                0.0         Personal
# 1  25.0   61959.0           Rent                9.0        Education
# 2  31.0   53088.0           Rent                0.0         Personal
# 3  27.0  225000.0       Mortgage               12.0  Homeimprovement
# 4  29.0   54000.0           Rent                0.0         Personal
#
#   internal_credit_rating  Loan_amount  Interest_rate  Loan_percent_income  \
# 0                      A       7000.0           6.54                 0.09
# 1                      C      25000.0          12.73                 0.40
# 2                      A       6000.0           6.54                 0.11
# 3                      A       6000.0           7.14                 0.03
# 4                      D      10000.0          14.96                 0.19
#
#   Default  Credit_history_length  Loan_status
# 0       N                    2.0        False
# ...

# %% [markdown]
# # Check point 3 - Feature Engineering

# %%
df_eda.columns
# Out:
# Index(['Age', 'Income', 'Home_ownership', 'Employment_length', 'Loan_intent',
#        'internal_credit_rating', 'Loan_amount', 'Interest_rate',
#        'Loan_percent_income', 'Default', 'Credit_history_length',
#        'Loan_status'],
#       dtype='object')

# %%
df_eda['Age'].sort_values(ascending=False).unique()
# Out:
# array([94., 84., 76., 73., 70., 69., 66., 65., 64., 63., 62., 61., 60.,
#        59., 58., 57., 56., 55., 54., 53., 52., 51., 50., 49., 48., 47.,
#        46., 45., 44., 43., 42., 41., 40., 39., 38., 37., 36., 35., 34.,
#        33., 32., 31., 30., 29., 28., 27., 26., 25., 24., 23., 22., 21.,
#        20.])

# %% [markdown]
# Standard age range is usually 18–60 years, extendable up to 65–70 depending on contex

# %%
df_eda['is_eligible'] = (df_eda['Age'] >= 18) & (df_eda['Age'] <= 60)
test_df['is_eligible'] = (test_df['Age'] >= 18) & (test_df['Age'] <= 60)

# %%
# Eligible persons to get the loan (Non Default Person)
df_eda[(df_eda['Loan_status'] == False) & (df_eda['is_eligible'] == True)]
# Out:
#         Age    Income Home_ownership  Employment_length        Loan_intent  \
# 0      23.0   75800.0           Rent                0.0           Personal
# 2      31.0   53088.0           Rent                0.0           Personal
# 3      27.0  225000.0       Mortgage               12.0    Homeimprovement
# 5      25.0   90000.0       Mortgage                4.0           Personal
# 6      21.0   54036.0       Mortgage                3.0            Medical
# ...     ...       ...            ...                ...                ...
# 25927  23.0   25000.0       Mortgage                4.0            Medical
# 25928  22.0   21600.0       Mortgage                4.0          Education
# 25929  28.0   81000.0           Rent               13.0            Venture
# 25930  30.0  100000.0       Mortgage               13.0           Personal
# 25931  22.0   33000.0           Rent                6.0  Debtconsolidation
#
# ...

# %%
# Train pe
# Train pe
df_eda['age_employment_ratio']   = df_eda['Employment_length'] / df_eda['Age']
df_eda['income_per_credit_year'] = df_eda['Income'] / (df_eda['Credit_history_length'])

# Test pe - same formulas, kuch fit nahi hota yahan
test_df['age_employment_ratio']    = test_df['Employment_length'] / test_df['Age']
test_df['income_per_credit_year']  = test_df['Income'] / (test_df['Credit_history_length'])

# %% [markdown]
# ## VIF

# %% [markdown]
# Most research papers consider a VIF (Variance Inflation Factor) > 10 as an indicator of multicollinearity, but some choose a more conservative threshold of 5.

# %%
# df_eda['Employment_length'] = df_eda['Employment_length'].astype(int)
# test_df['Employment_length'] = test_df['Employment_length'].astype(int)

# %%
# # function to calculate Variance Inflation Factor (VIF) for continuous features
# import pandas as pd
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# def calculate_vif(df, continuous_features):

#     # prepare dataframe for VIF calculation
#     vif = pd.DataFrame()
#     X = df[continuous_features]

#     # store feature names
#     vif['Variable'] = X.columns

#     # calculate VIF for each feature
#     vif['Vif'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

#     return vif

# %%
# calculate_vif(df_eda, df_eda.select_dtypes(include=['float', 'int']).columns)

# %%
# bins = [0, 18, 25, 35, 45, 60, 100]
# labels = ['<18', '18-25', '26-35', '36-45', '46-60', '60+']

# df_eda['age_group'] = pd.cut(df_eda['Age'], bins=bins, labels=labels)
# test_df['age_group'] = pd.cut(test_df['Age'], bins=bins, labels=labels)

# %%
# df_eda[(df_eda['Loan_status'] == False) & (df_eda['is_eligible'] == True)]['age_group'].value_counts()

# %% [markdown]
# 18-25 age group people got the more loan opportunity compare high age

# %% [markdown]
# Observation - Age columns has very multicolinarity value so we should remove it.....

# %%
# # drop Age column from dataframe
# df_eda.drop('Age', axis=1, inplace=True)

# # remove from test set for maintaning column structure
# test_df.drop('Age', axis=1, inplace=True)

# calculate_vif(df_eda, df_eda.select_dtypes(include=['float', 'int']).columns)

# %% [markdown]
# Observatio - Now everything is okay now no any any major issue Loan amount ~11 is acceptable....

# %%
# check skewness of continuous features
df_eda[df_eda.select_dtypes(include=['float', 'int']).columns].skew(axis=0, skipna=True)
# Out:
# Age                       1.926924
# Income                    1.718862
# Employment_length         1.254721
# Loan_amount               1.005903
# Interest_rate             0.202160
# Loan_percent_income       1.053640
# Credit_history_length     1.664383
# age_employment_ratio      0.591115
# income_per_credit_year    2.106697
# dtype: float64

# %% [markdown]
# Observation - Interest rate is normal,
#
# Income
# Employment_length
# Loan_amount
# Loan_percent_income
# Credit_history_length
# final_credit_score
#
# all are highly skewed

# %%
train_df = df_eda.copy()

# %%
# Save (industry common formats)
train_df.to_csv("../data/processed/transformed_train_df.csv", index=False)
test_df.to_csv("../data/processed/transformed_test_df.csv", index=False)

# %%
test_df.columns
# Out:
# Index(['Age', 'Income', 'Home_ownership', 'Employment_length', 'Loan_intent',
#        'internal_credit_rating', 'Loan_amount', 'Interest_rate',
#        'Loan_percent_income', 'Default', 'Credit_history_length',
#        'Loan_status', 'is_eligible', 'age_employment_ratio',
#        'income_per_credit_year'],
#       dtype='object')

# %%
train_df.columns
# Out:
# Index(['Age', 'Income', 'Home_ownership', 'Employment_length', 'Loan_intent',
#        'internal_credit_rating', 'Loan_amount', 'Interest_rate',
#        'Loan_percent_income', 'Default', 'Credit_history_length',
#        'Loan_status', 'is_eligible', 'age_employment_ratio',
#        'income_per_credit_year'],
#       dtype='object')
